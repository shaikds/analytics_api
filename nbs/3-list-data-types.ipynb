# %%
import requests
path ="/api/events"
base_url = "http://localhost:8002" # localhost == 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response = requests.get(endpoint)
print(response.ok)
if response.ok:
    data = response.json()
    print(data)
# Out:
# True
# {'results': [{'id': 1, 'description': '123', 'page': '/test+'}, {'id': 2, 'description': '123', 'page': '/test+'}, {'id': 3, 'description': '123', 'page': '/test+'}], 'count': 3}
