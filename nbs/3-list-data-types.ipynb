# %%
import requests
path ="/api/events"
base_url = "http://localhost:8002" # localhost == 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
from pprint import pprint 

response = requests.get(endpoint, params={'duration': '1 minute', 'pages': []})
print(response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# True
# [{'bucket': '2025-11-03T15:52:00Z', 'count': 2000, 'page': '/about'},
#  {'bucket': '2025-11-03T15:52:00Z', 'count': 1893, 'page': '/contact'},
#  {'bucket': '2025-11-03T15:52:00Z', 'count': 1921, 'page': '/pages'},
#  {'bucket': '2025-11-03T15:52:00Z', 'count': 1916, 'page': '/pricing'},
#  {'bucket': '2025-11-03T15:53:00Z', 'count': 70, 'page': '/about'},
#  {'bucket': '2025-11-03T15:53:00Z', 'count': 79, 'page': '/contact'},
#  {'bucket': '2025-11-03T15:53:00Z', 'count': 68, 'page': '/pages'},
#  {'bucket': '2025-11-03T15:53:00Z', 'count': 76, 'page': '/pricing'}]
